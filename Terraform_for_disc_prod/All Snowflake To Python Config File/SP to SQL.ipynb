# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import os
import snowflake.connector

# Replace these with your Snowflake account credentials and connection details
account = 'helpathome.east-us-2.azure'  # Replace with your Snowflake account URL
warehouse = 'DEMO_WH'
database = 'DISC_PROD'
schema = 'schemas'
username = 'dsingh'  # Replace with your Snowflake username
password = 'Hah@2023'  # Replace with your Snowflake password

#  Create the SQL_Files and Procedure folders
sql_files_dir = "SQL_Files"
procedure_dir = os.path.join(sql_files_dir, "stored procedure")
#procedure_dir = "stored procedure"
if not os.path.exists(sql_files_dir):
    os.mkdir(sql_files_dir)

if not os.path.exists(procedure_dir):
    os.mkdir(procedure_dir)

# Establish a connection to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema,
    role='SYSADMIN'
)

# Create a cursor to execute SQL queries
cursor = conn.cursor()
schemas = ['1UP_BISON','1UP_HEALTH','ACTIVE_DIRECTORY','ADMINPAYROLL','ALAYACARE','AMERIHEALTH','ASR','AXXESS','BI_REPOSITORY','CCSI','CENTENE',
'CLEARCARE','COSTALSYNCDATA','DATAFLEXSYNCDATA','DATA_CLEANSING','DATA_VAULT','DEVERO','DOCEBO','EMPEONEDISON','EMPEONPREFERRED','EMPLOYEESETUP',
'GENERATIONSALLIANCE','GPSYNCDATA','HAHUSERS','HAH_APP','HAH_REPORTING','HHAEXCHANGEEDISON','HHAEXCHANGEOPENSYSTEMS','HHAEXCHANGEOSHAH',
'HHAEXCHANGEPREFERRED','JAZZHR','LANDING_8X8','MATRIXCARE','MATRIXCARE_FULLLOAD','MOLINA','PARADOX','PAYLOCITY',
'PAYOR_CONTRACT_UI','PUBLIC','QUALTRICS_SURVEYS','RISKONNECT','SANDATAEXCHANGE','SANDATAIMPORT','TRUSTPOINTDATA','TRUSTPOINTDATA_HIST',
'VIVENTIUM','WORKDAY','ZENDESK']


# Query Snowflake to get a list of procedures in the specified database and schema


procedures = []
for schema in schemas:
# Execute the query to get the list of procedures
    procedure_query = f'''
    SELECT (procedure_catalog || '.' || procedure_schema || '.' || procedure_name) procedure_name, ARGUMENT_SIGNATURE
    FROM information_schema.procedures
    WHERE procedure_schema = '{schema}' AND procedure_catalog = '{database}'
    '''
    cursor.execute(procedure_query)
    procedure = cursor.fetchall()
    procedures.extend(procedure)
    

# Close the cursor and connection when done with the procedure query
cursor.close()

#
def extract_type(ip_string):
    ip_string_trimmed = ip_string.replace('(','').replace(')','')
    elements = [element.strip() for element in ip_string_trimmed.split(',')]
    dtypes = [element.split()[-1] for element in elements]
    result = ','.join(dtypes)
    return result

if procedures:
    # Iterate through the procedures and retrieve DDL statements
    for procedure_info in procedures:
        procedure_name = procedure_info[0]
        if '()' not in procedure_info[1]:
            procedure_details = extract_type(procedure_info[1])
            #print(procedure_details, '\n')
            ddl_query = f'''SELECT GET_DDL('PROCEDURE', '{procedure_name}({procedure_details})',true)'''
            #print(ddl_query, '\n')
        else:
            ddl_query = f'''SELECT GET_DDL('PROCEDURE', '{procedure_name}()',true)'''
            #print(ddl_query, '\n')

        # Construct the fully qualified procedure name
        fully_qualified_procedure_name = f'{procedure_name}'
        try:
            # Query to retrieve the DDL statement for the procedure

            # Create a new cursor for the DDL query
            cursor = conn.cursor()

            # Execute the DDL query
            cursor.execute(ddl_query)

            # Fetch the DDL statement
            ddl_statement = cursor.fetchone()[0]

            # Modify the DDL statement to include the database and schema names
            modified_ddl_statement = ddl_statement.replace(f'CREATE OR REPLACE PROCEDURE "{procedure_name}"',
                                                          f'CREATE OR REPLACE PROCEDURE {fully_qualified_procedure_name}')

            # Remove line breaks and extra spaces
            modified_ddl_statement = modified_ddl_statement.replace('\r\n', '\n').replace('\xa0', ' ').replace('\u2003', ' ')
        
            # Step 2: Create a .sql file and write the DDL statement to it
            sql_file_name = f"{procedure_dir}/{fully_qualified_procedure_name}.sql"
            with open(sql_file_name, 'w') as sql_file:
                sql_file.write(modified_ddl_statement.encode("utf-8").decode("utf-8"))

            # Step 3: Print the file name (database.schema.procedure name)
            print(f"Generated SQL file: ", sql_file_name)

            # Close the cursor for the DDL query
            cursor.close()
        except snowflake.connector.errors.ProgrammingError as e:
            print('Procedure does not exist or not authorized ', fully_qualified_procedure_name)
else:
    print(f"No procedures found in the specified schema '{schema}' in database '{database}'.")

# Close the connection
conn.close()
# Out:
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_DIAGNOSTICREPORT
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_PRACTITIONER
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_PROCEDURE
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_ORGANIZATION
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_ALLERGYINTOLERANCE
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_CONDITION
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_ENCOUNTER
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_RELATEDPERSON
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_COVERAGE
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_SERVICEREQUEST
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_PATIENT
# Procedure does not exist or not authorized  DISC_PROD.1UP_BISON.GET_FHIR_R4_OBSERVATION
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_CONDITION
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_OBSERVATION
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_ORGANIZATION
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_ALLERGYINTOLERANCE
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_PROCEDURE
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_RELATEDPERSON
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_PATIENT
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_SERVICEREQUEST
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_COVERAGE
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_DIAGNOSTICREPORT
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_ENCOUNTER
# Procedure does not exist or not authorized  DISC_PROD.1UP_HEALTH.GET_FHIR_R4_PRACTITIONER
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ACTIVE_DIRECTORY.HIST_ADUSERS_RAW_REFRESH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ACTIVE_DIRECTORY.LOAD_ADUSERS_RAW.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ACTIVE_DIRECTORY.ADUSERS_RAW_CURRENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ACTIVE_DIRECTORY.ADUSERS_RAW.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ACTIVE_DIRECTORY.GET_ADUSERS_RAW.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ADMINPAYROLL.GET_EMPLOYEEPTODATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ADMINPAYROLL.GET_PTOBANKDATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_INF_DISEASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_PROFILE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_PAY_CODE_RATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_REQUISITION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT_CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_ALLERGY_LIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_DEPARTMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_CODE_BILL_CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYMENT_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_GUID_PREMIUM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_MEDICATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_RRULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_SKILL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_APR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_BILLING_PERIOD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_PORTAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INVOICE_ITEM_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_GROUP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INVOICE_ITEM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_PAYROLL_ITEM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_BILL_RATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_DOCUMENT_APPROVAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_PAYCODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_GEOMAP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLAIMS_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_BACKUP_20220315.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_USER_ROLES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SKILL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_AVAILABILITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_CARE_PLAN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT_TAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLAIMS_HISTORICAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_ASSOCIATED.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_EXPERIENCED.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_TERMINATION_NOTE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_LABEL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_PAST_SURG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_ACCOUNTING_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_AUDIT_VISIT_EMPLOYEE_CHANGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_BILL_CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_BUDGET.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CATALOGUE_ITEMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLAIMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_BACKUP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_FACILITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_PREMIUM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLAIMS_V1.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMERGENCY_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_FACILITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INVOICE_ITEM_BILLING_PERIOD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_USER_RATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_DEPARTMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_OFFER_RESPONSE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_RISK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INTAKE_MESSAGES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_PAST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_DO_NOT_SEND.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_GUID_COST_CENTRE_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VITAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_SERVICE_DETAILS_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_WORK_SESSION_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_RATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT_ACTIVITY_CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_FUNDING_BLOCK_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_COST_CENTRES_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_JOURNAL_ENTRIES_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_WOUND.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_RULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INVOICE_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_FUNDER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT_DAILY_ACTIVITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_VISIT_RATING_FUNDER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_CURRENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_STAT_REQ.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_SKILL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_INVOICE_TAXES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLAIMS_V2.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_RECENT_HOSP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EVV_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_TAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_GROUPS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_GUID_RELATION_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_MEDHIST_IMM_HIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_COMPUTED_VISIT_WORK_SESSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_SERVICE_CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_TBL_ACC_INVOICE_TIER_4.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ALAYACARE.GET_CLIENT_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AMERIHEALTH.GET_AMERIHEALTH_SOURCE_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEE_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_AGINGREPORT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_BILLINGCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_TASKASSIGNMENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_BILLABLESERVICEVISITSREPORT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CASEWORKERS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CUSTOMER_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEETYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CUSTOMERS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_SUPERVISORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CUSTOMERSTATUSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_SERVICETYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_PAYMENTSRECEIVED.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_TERMINATIONREASONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CUSTOMERTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_BILLINGSUMMARY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEESTATUSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_PLANOFSERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_PROGRAMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_VISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CLAIMSTATUSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEETRAININGLICENSESCERTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEE_SALARY_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_TASKS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_COUNTIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_PAYERSOURCES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_RECEIVABLES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_CUSTOMERSCOMMUNICATIONLOG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_REVIEWTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_EMPLOYEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_LOCATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ASR.GET_ASR_SPECIALTRAINING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_CLIENTINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_AUTHORIZATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_INSURANCEFEESCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HOMECARE_REFERRALS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_BILLINGPERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_BRANCHINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_CAREPERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_HOMEHEALTH_INSURANCEPAYERLIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_VISITFINANCIALS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_BRANCHINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_PATIENTVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_WORKERDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_ARS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_AGENCYINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_AUTHORIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_FEESCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_CLIENTINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_EPISODESNAPSHOTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_AGENCYINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_EMPLOYEE_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_BRANCHINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_PATIENTDIAGNOSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_PATIENTINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HC_EMPLOYEEINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_EMPLOYEEINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_EMPLOYEE_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_STAGE_AXXESS_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HOMEHEALTH_INSURANCEPAYERLIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_TASKDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_VISITINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_EMPLOYEEINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_FINANCIALTRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_REFERRALS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_HH_AUTHORIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_STAGE_AXXESS_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.AXXESS_BRANCH_OFFICE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_EVVVISITEXCEPTIONDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.AXXESS.GET_AXXESS_PAYMENTSOURCES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_EXTERNALIDS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_LOCATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_AUTHENTICAREMAPPINGIDS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_KMOFFICEBUDGETS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_SANDATAVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_EXTERNALCONTRACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_AUTHENTICAREVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_ALAUTHENTICAREAAAS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_ALAUTHENTICARECONTRACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_KMREGIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.BI_REPOSITORY.GET_GA_COASTALALTRUS_DEPARTMENTMAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_EMPLOYEE1.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_EMPROSTER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GENERATE_FLAGS_MASTERCLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_MASTERCLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_ACTIONTYPECHANGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_CLAIMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_EVVNOTES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_OTHERINV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_ACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_CLIENTCALL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_EMPCALL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_DESKINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_FMLA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_CALLSFIELD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CCSI.GET_RAWVRFP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CENTENE.GET_.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CENTENE.GET_CENTENE_SOURCE_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_BILLRATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVEREMERGENCYCONTACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FAMILY_ROOM_FAMILYROOMMESSAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FRANCHISES_FRANCHISEOWNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLAN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLAN_ALLERGIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_CHECKRFRANCHISEACCOUNT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_OPEN_SHIFTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYLOCATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_PAYRATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FAMILY_ROOM_FAMILYEVENT_GUESTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FRANCHISES_FRANCHISORACTIVITYTAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_LIFEACTIVITYTASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SCHEDULEEXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_AGENCYSAFETYPROGRAM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_UB04REVENUECODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ACTIVITY_ACTIVITY_RELATED_TO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ACTIVITY_ACTIVITY_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYCOUNTRY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVEREMPLOYMENTHISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CARELOGS_CARELOG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PAYMENT_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_GEOCODINGREQUEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_CAREGIVERRATESCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_HOLIDAYS_AGENCYHOLIDAY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PATIENTCONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_SAFETYRECORD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_HOSPITALIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_REPORTS_REPORTDATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYMATCHINGCRITERIA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCY_AGENCY_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_CLIENTAUTHORIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVERSKILLSEDUCATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVER_DEFAULT_RATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_HOLIDAYS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_SETTINGS_REQUIREDFORMFIELDS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FAMILY_ROOM_FAMILYEVENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTREPORTCHECKLIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_CHANGEINCONDITIONOBSERVATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_RATEPOLICY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FRANCHISES_FRANCHISORTAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_MEDS_PRESCRIPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CARELOGS_CARELOGREVISION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CARELOGS_TASKCOMMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLAN_ICD10_CODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PROFILEFILE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_ADJUSTMENTBATCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PAYMENTS_AUTOPAYRULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_INVOICE_ITEMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_ITEM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CARELOGS_SIGNATURE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PARENTPAYER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_ESREPORT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_HOSPITALIZATION_ASSIGNEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_ADJUSTMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_CLIENTACTIVITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_CLIENTRATESCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_APPLICANTANSWER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTACTIVATIONRECORD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_CHANGEINCONDITION_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_LEADSTATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_PREPAYMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLACE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_CHANGEINCONDITION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_PAYMENTITEMDESIGNATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_PARTNERSHIP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_ESDOCUMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ACTIVITY_ACTIVITY_ASSIGNEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYADMINLOCATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYCERTIFICATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_APPLICANTSTATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_RECEIVABLESBALANCE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_INVOICE_CLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVERPROFESSIONALREFERENCES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLANICD10CODEWITHEXTRAS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_PAYMENTDESIGNATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTCARENEEDSPLAN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_REFUNDDESIGNATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYSURCHARGESETTINGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVERACTIVATIONRECORD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_ESADMIN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_LIFEACTIVITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FRANCHISES_FRANCHISORCUSTOMFIELD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PROFILETAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PROFILE_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTPLAN_ICD9_CODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PROFILECERTIFICATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_SAFETYTASKNOTE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ACTIVITY_ACTIVITYTAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_COMMUNITYTASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_COMMUNITYTASKSET.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_RATECATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVERUNAVAILABILITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_CLIENTTASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_CLIENTMATCHINGCRITERIA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTREPORT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCIES_FRANCHISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYCUSTOMFIELD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_REFERRAL_SOURCES_REFERRALSOURCE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_REFERRAL_SOURCES_REFERRALSOURCETYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_CLIENTTASKEXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_FRANCHISES_FRANCHISORPROFILETAG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_INVOICE_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_CHANGEINCONDITION_ASSIGNEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_PERSONCLASSCODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_REFUND_TRANSACTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CARELOGS_TASKLOG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AUTH_USER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_APPLICATIONFORMSETTING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_LOGIT_CHANGELOG.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_LOGIT_USERLOGIN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENT_CACHED_RELATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFTFCFSEVENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_SAFETYTASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_MANIFEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_TASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYADMIN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVERCERTIFICATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_AGENCYINSURANCECARRIER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_QUALITY_CARE_HOSPITALIZATION_TAGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ACTIVITY_ACTIVITY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_ASSESSMENT_CLIENTTASKINSTANCE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_SCHEDULEDITEM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENT_DEFAULT_RATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_INVOICE_CARELOGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_CAREGIVER_MATCH_CRITERIA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_ESVENDORACCOUNT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PARENTPAYERSERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PATIENT_AGENCYLOCATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PROFILE_PROFILE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFT_COMMUNITY_TASK_SETS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFTFCFSCLAIMED.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFTNOTE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_AGENCY_AGENCYCAREGIVERCERTIFICATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_RATESCHEDULE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_BILLING_ROUNDINGPOLICY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_EMPLOYMENT_SCREENING_ESCANDIDATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_CAREGIVER_APPLICANTQUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_PATIENT_PATIENTICD9CODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_WORKERS_COMPENSATION_SAFETYTASK_ASSIGNEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_RECEIVABLES_PREPAYMENTDESIGNATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.CLEARCARE.GET_SCHEDULES_SHIFT_OCCURENCE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDCHGTRN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDPLFPPN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_GPALLPAYCHECKSBASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CPTSKFREQ.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MONTHLYHOURS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPLANCOPAYDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_GPALLPAYCHECKDETAILSBASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTCATEGORYRATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PROVIDERCATEGORIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PHYSICIANORDERTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_BILLINGTRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CPTSKCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PAYLOCATIONFACILITYPLANSHIFT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_REFERRINGSOURCECODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_GPALLEMPLOYEERATESBASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_ICDCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPLANRATEDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PHYSICIANORDERSHEADERS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PLANTIMETRANSLATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_DEPARTMENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_DISCIPLINES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_EMPLOYEEPROFILECODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_FACILITIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_FACILITYPLANPROCRATEDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PAYEMPLOYEESERVICECATEGORYSHIFT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_GPALLEMPLOYEESBASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CLNCPTSKCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_DISCIPLINEFREQUENCIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDGUADAT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MEDICATIONTABLES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_PAYCODE_CATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDLICCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_RELATIONSHIPCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PROFESSIONALCONTACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PROFESSIONALCONTACTTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PAYSERVICECATEGORYSHIFT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_BILLINGDATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_FACILITYTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_LOCATIONOFFICEBREAKDOWN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPLANS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTCERTIFICATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPROFESSIONALCONTACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PERSONALCONTACTTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_ADMISSIONDIAGNOSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_EVVCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PROVIDERPLANLOCATIONPROCDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_SCHEDULES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MEDICATIONROUTES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_GPALLPAYCODESBASE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_EMPLOYEESTATUSCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDPROCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PAYPATIENTPLANEMPLOYEESERVICECATEGORYSHIFT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_FDB_ROUTES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CHARGES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CLINICALTASKCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_EMPLOYEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDPRVCDE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_SERVICECATEGORYCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_CPCARPLN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_MDPPRDET.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPLANCOPAYS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_NURSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTCERTIFICATIONDIAGNOSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_SCHEDULESPLITSHIFTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_FDB_DISPENSABLES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_ADMISSIONADMITDIAGNOSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_EMPLICENSEINFO.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_LOCATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PAYGLOBALFACTORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PATIENTPERSONALCONTACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_ADMISSIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PLANRATEDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.COSTALSYNCDATA.GET_CV_PLANS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFINVOICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFSCHEDULEAUTHORIZATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFINVOICEDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFEMPLOYEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFSERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFHOLIDAYS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFTIMESHEETHOURS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFBILLPERSONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_IL_INVDTLOL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFOFFICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFBILLCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFSUPERVISORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.DERIVED_BILLRATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFINVOICEPAYMENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFPAYMENTDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFARPAYMENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCONTRACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTSUPERVISORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFREVENUESUBCATEGORIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFSCHEDULEITEMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTCONTRACTAUTHORIZATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTCONTRACTRATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTCONTRACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFARINVOICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFMOVEDHOURS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFPAYMENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFSCHEDULES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFBILLRATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFCLIENTADDRESSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATAFLEXSYNCDATA.GET_DFTIMESHEETS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_ADPALLIANCE_SRC_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_EMPEONPREFERRED_SRC_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.MERGE_STAGE_DAT_CLEANSING_STD_EMPLOYEE_MITUL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_COSTALSYNCDATA_SRC_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_EDISON_SRC_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_SANDATAIMPORT_SRC_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_SANDATAIMPORT_SRC_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.DATA_CLEANSING.GET_ALAYACARE_SRC_EMPLOYEE.sql
# ...
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_PAYOR_CONTRACT_MAPPING_BKP_08JUN23.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_PAYOR_CONTRACT_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_REVENUE_CATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_REVENUE_CATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_PARENT_PAYOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_PARENT_PAYOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_PAYOR_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_REVENUE_SUBCATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_PAYOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_PAYOR_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_CONTRACT_MIGRATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_PAYOR_CONTRACT_MAPPING_BKP_08JUN23.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.LOAD_PAYOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PAYOR_CONTRACT_UI.GET_REVENUE_SUBCATEGORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.DISCOVERY_LAYER_SYNC.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.HIST_STVHC_T_AUTHORIZATIONDATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.TEST_SQL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.LOAD_SAT_EMPLOYEE_SANDATA.sql
# Procedure does not exist or not authorized  DISC_PROD.PUBLIC.sp_AUDIT_ALAYACARE_ROWCOUNT
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_MASTER_FACT_DATABASE_USAGE_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.BACKUP_DISC_PROD_SP.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.INSERT_AUDIT_END_TASK.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.TEST_RSUTHAR2.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_MASTER_FACT_WAREHOUSE_CREDIT_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.RIGHT_BIND.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_INVOICE_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.TESTING_RETURN_STATEMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.SP_TIMESHEET_CONFIRMATION_RESPONSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.RIGHT_BIND.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_SERVICE_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.GET_STAGE_CARE_COORDINATION_OBSERVATION_RESPONSE_ANSWER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.OUTPUT_MESSAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.PYTHON_CODE_TESTING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.OUTPUT_MESSAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.PUBLIC.PROCEDURE_DDL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_DIRECTORY_CONTACTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.LOAD_DISC_QUALTRICS_SURVEY_RESPONSE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_SURVEY_DISTRIBUTION_LIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.LOAD_DISC_QUALTRICS_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_SURVEY_RESPONSE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.LOAD_DISC_QUALTRICS_SURVEY_LIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_CC_BOUNCED.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_SURVEY_DISTRIBUTION_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_QUALTRICS_SURVEY_LIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.QUALTRICS_SURVEYS.GET_CC_OPT_OUT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_HC_AMBULATORY_EVENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_WORK_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_CONTACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_PROPERTY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_VEHICLE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_CLAIM.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_HC_NON_CLINICAL_EVENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_HIERARCHY_NODE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.RISKONNECT.GET_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_DFIMPORT_DATAFLEXTIMESHEETVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_DFIMPORT_DATAFLEXTIMESHEETS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_DFIMPORT_SANDATAVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_DFIMPORT_DATAFLEXTIMESHEETSANDATAVISITMAPPINGS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_DFIMPORT_IMPORTVISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAEXCHANGE.GET_OPENSAM_CLIENTADMISSIONTYPES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CURRENTSCHEDULESCLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CURRENTSCHEDULESSTAFFS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_REFERRALSOURCES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_SCHEDULESCLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ADMISSIONDIAGNOSES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_EVENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_STAFFS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_AUTHORIZATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CLIENTMEDICATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_INVOICEDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_POSITIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ADMISSIONSPAYORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_INVOICEEXPORTHISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_STAFFSTATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ADMISSIONSCERTIFICATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_EVENTCANCELS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_PHYSICIANS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_REJECTIONCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_SCHEDULES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_VISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ADMISSIONPLANOFCARETASKS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_EXCEPTIONCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_SCHEDULESSTAFFS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_SCHEDULESTASKS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_TIMESHEET_SANDATAAGENCYSTATES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CURRENTSCHEDULEIDS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_INVOICEHEADER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_EXTERNALREASONCODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_LOCATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_PAYMENTDETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_PAYORS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ADMISSIONSERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_CLIENTADMISSIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_ORDERS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.SANDATAIMPORT.GET_SANDATA_PAYMENTHEADER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.GET_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.PAYROLL_DETAILS_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.HIST_EMPLOYEE_REFRESH.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.EMPLOYEES_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.GET_EMP_MATCH_TRUSTPOINTDATACOASTAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.PAYROLLDATA_DELETE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.LOCATIONS_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.EMPLOYEE_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.GET_EMPLOYEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.EMPLOYEES_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.PAYROLL_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.PAYROLL_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.GET_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.PAYROLL_DETAILS_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA.LOCATIONS_LOAD_2.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.PAYROLL_DETAILS_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.PAYROLL_DETAILS_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.GET_EMP_MATCH_TRUSTPOINTDATACOASTAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.EMPLOYEES_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.EMPLOYEES_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.PAYROLL_CV.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.PAYROLLDATA_DELETE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.TRUSTPOINTDATA_HIST.PAYROLL_LOAD.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.VIVENTIUM.GET_EXPORTCHECKS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.VIVENTIUM.GET_LMSEXPORTEMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.VIVENTIUM.GET_EXPORTEMPLOYEES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.VIVENTIUM.GET_EXPORTCHECKS_UNFLATTEN.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.VIVENTIUM.GET_PAY_CODES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_RELATED_PERSON_PHONE_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_PERSONAL.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_SUMMARY.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_RELATED_PERSON_ADDRESS_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_QUALIFICATIONS_CERTIFICATION_ACHIEVEMENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_EXCLUDE_LIST_POST_PROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_AUDIT_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_RELATED_PERSON_EMAIL_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_MASTER_WORKDAY_DISCOVERY_LAYER.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_RELATED_PERSON.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_ORGANIZATION_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_POSITION_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_RELATED_PERSON_NAME_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_ADDITIONAL_INFORMATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_REMOTE_LOCATIONS_POST_PROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_LEAVE_OF_ABSENCE.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_COMPENSATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_IDENTIFICATION_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_AUDIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.WORKDAY.GET_WORKER_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_TICKETS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_SLA_POLICIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_TICKET_CUSTOM_FIELDS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_TICKET_METRICS_EVENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_ORGANIZATIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_CALLS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_TICKET_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_GROUPS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_TICKET_FORMS.sql
# Generated SQL file:  SQL_Files\stored procedure/DISC_PROD.ZENDESK.GET_USER.sql
