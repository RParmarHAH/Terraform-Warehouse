# %%
import warnings
import os
import snowflake.connector

warnings.filterwarnings("ignore", category=DeprecationWarning)

# Replace these with your Snowflake account credentials and connection details
account = ''  # Replace with your Snowflake account URL
warehouse = 'DEMO_WH'
database = 'DW_PROD'
schema = 'schemas'
username = ''  # Replace with your Snowflake username
password = ''  # Replace with your Snowflake password

# List of schemas to iterate through
schemas = ['ACROSS_DEDUPE','HAH','INTEGRATION','PUBLIC','REPORT','STAGE']

#  Create the SQL_Files and Table folders
sql_files_dir = "SQL_Files"
table_dir = os.path.join(sql_files_dir, "Table")

if not os.path.exists(sql_files_dir):
    os.mkdir(sql_files_dir)

if not os.path.exists(table_dir):
    os.mkdir(table_dir)

# Establish a connection to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database
)

for schema in schemas:
    # Create a cursor to execute SQL queries
    cursor = conn.cursor()

    # Query Snowflake to get a list of tables in the specified database and schema
    table_query = f'''
        SELECT (table_catalog || '.' || table_schema || '.' || table_name) table_name
        FROM information_schema.tables
        WHERE table_schema = '{schema}' AND table_catalog = '{database}' AND TABLE_TYPE = 'BASE TABLE'
    '''

    # Execute the query to get the list of tables
    cursor.execute(table_query)

    # Fetch the results
    tables = cursor.fetchall()

    # Close the cursor when done with the table query
    cursor.close()

    if tables:
        # Iterate through the tables and retrieve DDL statements
        for table_info in tables:
            table_name = table_info[0]

            # Construct the fully qualified table name
            fully_qualified_table_name = f'{table_name}'
            try:
            
                # Query to retrieve the DDL statement for the table
                ddl_query = f'''
                SELECT GET_DDL('TABLE', '{table_name}',true)
                '''

                # Create a new cursor for the DDL query
                cursor = conn.cursor()

                # Execute the DDL query
                cursor.execute(ddl_query)

                # Fetch the DDL statement
                ddl_statement = cursor.fetchone()[0]

                # Modify the DDL statement to include the database and schema names
                modified_ddl_statement = ddl_statement.replace(f'create or replace TABLE {table_name}',
                                                            f'CREATE OR REPLACE TABLE {fully_qualified_table_name}')

                # Step 2: Create a .sql file and write the DDL statement to it
                sql_file_name = f"{table_dir}/{fully_qualified_table_name}.sql"
                with open(sql_file_name, 'w') as sql_file:
                    sql_file.write(modified_ddl_statement)

                # Step 3: Print the file name (database.schema.table name)
                print(f"Generated SQL file: {sql_file_name}")

                # Close the cursor for the DDL query
                cursor.close()
            except snowflake.connector.errors.ProgrammingError as e:
                print('Table does not exist or not authorized ', fully_qualified_table_name)
    else:
        print(f"No tables found in the specified schema '{schema}' in database '{database}'.")

# Close the connection
conn.close()
# Out:
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_AL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_DE_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_GA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_IN_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_MICH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_MS_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_NY_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_OH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_AL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_DE_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_IN_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_MICH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_MS_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_NY_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_OH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_PAYROLL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_PA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_CLIENT_PA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.ACROSS_DEDUPE.DIM_EMPLOYEE_GA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.AMS_PARADOX_BRANCH_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.AMS_PARADOX_BRANCH_MAPPING_BKP_12_20.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.AMS_PARADOX_BRANCH_MAPPING_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.AMS_PARADOX_BRANCH_MAPPING_TEST_1.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.AMS_PARADOX_BRANCH_MAPPING_TEST_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.CLIENT_SATISFACTION_SURVEY_Q3_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.CONTRACT_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.CONTRACT_MAPPING_BKCP_11032023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_APPLICANT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BILLCODE_TO_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_BCKP_SS_01152024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP_11222023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP_12152023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP_12182023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP_12192023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BACKUP_20230831.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_09272023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_COMPANY_STATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_COMPANY_STATE_NEW.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_27102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_BCKP_121223.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_BKCP_09252023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_GEOGRAPHY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_VISIT_LINKAGE_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_PARTNER_PROGRAM_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_STATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_VISIT_EXCEPTION_MAPPING_LEVELS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_APPLICANT_WITH_PDR_STATUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_AREA_DEPRIVATION_INDEX.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BRANCH_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_ACTIVITIES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BILL_PERSON.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_BKCP_11282023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_11212023_PRODREFRESH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_CLONE_25012024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_TEST1.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_DIAGNOSIS_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SOURCE_SYSTEM.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_ZIP_CODE_DETAILED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_APPLICANT_STATUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BUDGET.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_ACQUIRED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_ACQUIRED_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_SUBCATEGORY_USAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_RESPONSE_SCALE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_BKCP_09152023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.GATOR_SURVEY_QUESTION_KEY_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BILLING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_BRANCH_REGION_MAPPING_SS_BCKP_02052024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_07_27_2023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_10182023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_11082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_DATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_DISTRIBUTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_11092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_BKCP_11102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_BKCP_11282023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_438857.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_JAZZHR_PARADOX_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_JOB.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_REFERRER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BACKUP_29122023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BCKP_02152024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BCKP_08242023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BCKP_08252023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BCKP_131223.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_APPLICANT_STATUS_BKP_22_01_2024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_APPLICANT_STATUS_TEST_2023_10_04.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BRANCH_MANAGER_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BUDGETT_BKCP_20230802.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_BUDGET_BKCP_12152023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_ACQUIRED_WEEKLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_ACQUIRED_WEEKLY_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_SERVICE_TEMP_AUTH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_COMPANY_STATE_SYSTEM.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_CLIENT_BKCP_20112023_AFTERPIPELINE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_PARENT_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_SURVEY_RESPONSE_HEADER_BCKP_01082024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CAREGIVER_TOUCH_POINT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CASH_INFLOW.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_ACQUIRED_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_DISTRIBUTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_EMPLOYEE_ACQUIRED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_EMPLOYEE_ACQUIRED_WEEKLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_EVV_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_EVV_VISIT_EXCEPTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_GAPS_IN_CARE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_INTAKE_BKCP_2023_08_04.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_INVOICE_CREDITS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_20231125.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_438857.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_MONTHLY_20231125.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SLA.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_RESPONSE_DETAIL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SYSTEM_CUTOVER_DATE_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_TICKET_14_08_BACKUP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_438857.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_DARSHAN_18_JULY_23_277132.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_WRITEOFF.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_EMPLOYEE_BKCP_11102023_PRODREFRESH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_ZIP_CODE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CALLS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_CLIENT_STATUS_HISTORY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_DOCEBO_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_EMPLOYEE_ACQUIRED_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_INVOICE_TRACKING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_REVENUE_SUBCATEGORY_CONTRACT_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_COLUMN_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_OPTOUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_QUESTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SURVEY_RESPONSE_DETAIL_BCKP_08242023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_TICKET_19JUL23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_BKCP_02112023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_BKCP_09262023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.SALIMAH_Q1_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.SALIMAH_Q2_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.SOURCE_SYSTEM_MIGRATION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_ORPHAN_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.DIM_VISIT_EXCEPTION_09222023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_PARTNER_CONTRACT_SERVICE_CLONE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_SYSTEM_CUTOVER_DATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.FACT_TICKET.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.MDM_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.HAH.MOLINA_EXCLUDE_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_AL_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_GA_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_IL_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_IN_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_MAPPING_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_MI_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_OH_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_PA_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_CROSSWALK_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_CROSSWALK_DEDUPE_OUTPUT_CLEANUP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_CROSSWALK_E2E_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_CROSSWALK_MAPPING_CLEANUP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_EMPLOYEE_DEDUPE_OUTPUT_NEW.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_WORKDAY_EMPLOYEE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.CARE_COORDINATION_CAREGIVER_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.CLIENT_CROSS_WALK.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.CLIENT_CROSS_WALK_BAKUP_26092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DATAFLEXSYNCDATA_MATRIXCARE_EMPLOYEE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DATAFLEX_MATRIXCARE_CLIENT_MAPPING_IN_MI.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DEFAULT_SYSTEM_STATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_BRANCH_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_AL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_AMERIHEALTH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_CENTENE_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_DE_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_IN_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BKCP_11082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MOLINA_RL_OUTPUT_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MOLINA_RL_OUTPUT_CLONE25012024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_AMS_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_GA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MASTER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MICH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_NY_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_MERGE_WORKDAY_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.AMS_PAYROLL_NY_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_CROSSWALK_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.APPLICANT_EMPLOYEE_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.CARE_COORDINATION_CLIENT_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.CLIENT_CROSS_WALK_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_GA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BKCP_11092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MOLINA_RL_OUTPUT_BAKUP_26092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_OH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_AL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MS_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MOLINA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_RL_OUTPUT_WORKDAY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_SURVEY_RESPONSE_HEADER_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10062023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_11072023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240116.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_HISTORICAL_HOURLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_APPLICANT_EMPLOYEE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_NPS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_PAYROLL_MERGE_27102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_REVENUE_MERGED_20231125.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ZENDESK_WH_AMS_MAPPING_TBL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DF_CCSI_VISIT_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DF_CCSI_VISIT_DEDUPE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_AMERIHEALTH_RL_OUTPUT_BAKUP_26092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_CENTENE_RL_OUTPUT_CLONE_25012024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BKCP_10182023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BKCP_11212023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BKCP_2023_07_27.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_CLONE25012024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MS_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_DE_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_IN_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MATCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MERGED_DEDUPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_OH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE_27102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE_BCKP_121223.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_SUPERVISOR_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10032023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10072023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10122023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10132023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_CHANGE_LOG.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240104.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240109.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240123.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_TEMP_FOR_DUPS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_CENTENE_RL_OUTPUT_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_CENTENE_RL_OUTPUT_BAKUP_26092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MATCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MERGED_BAKUP_24072023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_NY_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_PARTNER_CONTRACT_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_10112023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240208.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_OLD_NEW_ID_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_WD_02OCT23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_WD_03OCT23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_WD_09OCT23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMP_GA_DEDUPE_SOURCE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_BRANCH_PAYROLL_PERIODS_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_PARTNER_CONTRACT_SERVICE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_PAYROLL_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_REVENUE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_SURVEY_QUESTION_RESPONSE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.JAZZHR_PARADOX_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.PARADOX_EMP_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.SOURCE_SYSTEM_MAPPING_FOR_KEYRING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.TEST_DIM_CLIENT_PA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.VW_EMPLOYEE_CROSS_WALK_TBL_MASTER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.WORKDAY_CROSSWALK_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.WORKDAY_X_ATTRIBUTE_COMPARISION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ZENDESK_AMS_MAPPING_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ZENDESK_PAYROLL_MAPPING_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ZENDESK_WH_PAYROLL_MAPPING_TBL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MASTER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_MICH_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_CLIENT_PA_RL_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_AMS_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MERGED_BKCP_11102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_NY_RL_OUTPUT_BACKUP_20231116.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_09192023_M.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_11162023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_22NOV23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_EXCEPTION_WD_ID.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_FJN_BKUP_20240130.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_HISTORICAL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_BUDGET_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_CLIENT_SERVICE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_INTAKE_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_PAYROLL_DETAILS_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_QUESTION_CHOICE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_VISIT_MERGED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.JAZZHR_PARADOX_MASTER_LIST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.PAYROLL_WORKDAY_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.WORKDAY_CROSSWALK_DEDUPE_OUTPUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE_16102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_WD_25SEP23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_PAYROLL_MERGED_16102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_SURVEY_QUESTION_MAPPING_BCKP_0927.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.DIM_EMPLOYEE_MERGED_16102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.EMPLOYEE_CROSS_WALK_WD_28AUG23.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_AMS_PAYROLL_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_SURVEY_QUESTION_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_SURVEY_QUESTION_MAPPING_BCKP_29092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.FACT_SURVEY_QUESTION_MAPPING_BCKP_09272023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ROSTER_AMS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.INTEGRATION.ROSTER_AMS_MAPPING_HISTORY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.ACROSS_DEDUPE_CONFIG.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.ACROSS_DEDUPE_CONFIG_FINAL_AWS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.ALL_EMPLOYEES_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.APPLICANT_WORKDAY_EMPLOYEE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.CLIENTS_REFER_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.CLIENT_TENURE_DERIVED_MONTHLY_METRICS_BKCP_19102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.CROSSWALK_EXTERNAL_UPDATES_TRACKING_HOURLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DATAFLEXSYNCDATA_DIM_EMPLOYEE_SS_BCKP_01312024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DATAFLEXSYNCDATA_FACT_CLIENT_SERVICE_BACKUP_20240209.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DATAFLEXSYNCDATA_FACT_VISIT_BCKP_08102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DFINTAKE_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DF_INTAKE_DELETE_2023_08_04.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_BRANCH_REGION_MAPPING_SS_BCKP_02022024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE_12022024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_EMPLOYEE_PAYROLL_MERGE_DEDUPE_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_EMPLOYEE_PAYROLL_MERGE_WORKDAY_TEST2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_CHANGE_LOG_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_TEMP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_MV_BEFORE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.FACT_INTAKE_BKCP_20230807.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.OPENSYSTEMS_FACT_VISIT_BCKP_01082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.OSHAH_FACT_VISIT_BCKP_01082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.SANDATAIMPORT_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.UTILIZATION_PROD_MV.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_BRANCH_MERGED_BCKP_09152023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_HISTORICAL_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_TEMP_FOR_DUPS_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.WORKDAY_DIM_EMPLOYEE_16012023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_MERGED_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.UTI_UPDATED_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.COSTALSYNCDATA_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DATAFLEXSYNCDATA_FACT_VISIT_BCKP_08092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EDISON_FACT_VISIT_BCKP_01082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EMPLOYEE_CROSS_WALK_01022024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_MV_AFTER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.PAYROLL_WORKDAY_MAPPING_12022024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.VW_HOURS_AND_CENSUS_BUDGETEDDATA_WEEKLY_SS_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.WORKDAY_PAYROLL_MISMATCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DF_INTAKE_DELETE_2023_08_04_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.SANDATAIMPORT_FACT_INTAKE_MV_COMP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.VW_EMPLOYEE_CROSS_WALK_TBL_MASTER_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.COSTALSYNCDATA_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.WORKDAY_PAYROLL_MISMATCH_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.DIM_CLIENT_MERGED_BKCP_09272023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.PUBLIC.UTI_UPDATED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ACCOUNTS_RECEIVABLE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ACCOUNTS_RECEIVABLE_AGING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ADMIN_EXIT_SURVEY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ARCHIVED_CC_CLIENT_CARE_PROGRAM.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.BUSINESS_TO_BUSINESS_AUDIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CAREGIVER_BUDGET_22.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CAREGIVER_LINEAR_RETENTION_FORWARD_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CAREGIVER_LINEAR_RETENTION_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CC_LEGACY_OSH_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CGR_OBS_SURVEY_RESPONSES_CC.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CGR_OBS_SURVEY_RESPONSES_CC_BCKP_18092023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_REACTIVATED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_REFERRED_BKCP_07_27_2023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CENSUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_SEC.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_WEEKLY_VISIT_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_LINEAR_RETENTION_FORWARD_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_LINEAR_RETENTION_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_SERVICE_WEEKLY_AUTHORIZATION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_TENURE_DERIVED_MONTHLY_METRICS_BKCP_11242023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_DAILYVISITHOURSCOUNTRECENT4WEEKS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_EVV_VISITS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_ON_HOLD_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.DISCOVERY_TO_BUSINESS_AUDIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_ACTIVE_630_ANALYSIS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_W_BILLABLE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_PHONE_NUMBERS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.GP_EMPLOYEE_LIST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.GP_EMPLOYEE_LIST_WITH_PAYCODE_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BILLED_HOURS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.NPS_CAREGIVER_SCORE_BCKP_09272023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.OVERTIME.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CAREGIVER_EXIT_SURVEY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_REFERRED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CENSUS_BY_PAYROLL_DATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CENSUS_WIP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_COUNT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_DAILYVISITHOURSCOUNT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_NEW_REFERRALS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_WEEKLY_METRICS_BY_SERVICE_LINE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_WEEKLY_VISIT_METRICS_27_SEP_2023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.FACT_APPLICANT_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.GP_HOURS_WORKED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.MATRIXCARE_GP_EMPLOYEE_WITH_PAYCODE_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.PAYPERIOD_GROUP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_050124.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_REFERRED_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_SUPERVISOR_BY_SERVICE_WEEK.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_AUTH_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_UNIQUE_REOCRD_010923.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_UNBILLED_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.SCHEDULE_METRICS_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_2_0_WIP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CALL_TICKET.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_STARTED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CENSUS_BY_SERVICE_DATE_WEEKLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_CONVERSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_CLS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_CLS_W_BILLABLE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_FJN.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_GAPS_IN_CARE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_SERVICE_MONTHLY_AUTHORIZATION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_SERVICE_MONTHLY_AUTHORIZATION_TEMP_AUTH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_DAILYCLIENTCOUNT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_SF_EXTERNAL_DATA_VISITS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_WEEKLY_VISIT_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_SUPERVISOR_BY_SERVICE_MONTH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.GP_CROSSWALK_LIST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.GP_EMPLOYEE_LIST_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE_DAILY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CLIENT_CENSUS_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.NPS_CAREGIVER_SCORE_BCKP_01082024.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.NPS_CAREGIVER_SCORE_BCKP_11012023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.NPS_CLIENT_SCORE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ONHOLDCLIENTHISTORY_PA.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.PAYROLL_EMPLOYEE_DERIVED_WEEKLY_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_1202.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_BACKUP_051023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_BACKUP_210923.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_TASK.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_TASK_BACKUP_051023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_UNBILLED_METRICS_MONTHLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.SCHEDULE_METRICS_WEEKLY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.TAKING_MONTHLY_SNAPSHOT_FOR_RCM_TABLES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.TIME_TO_COLLECT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.TOP_OFFENDERS_EXCEPTION_DETAILS_BY_WEEK.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_REFERRED_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_SERVICE_MONTHLY_AUTHORIZATION_BKCP1310.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_OVERTIME_HOURS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_MONTHLY_TASK_050124.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_2_0_AUTH_TEMP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.SANDATA_AUTH_EXCLUDE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_2_0_WIP_NEW.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_WEEKLY_2_0_WIP_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.WORKDAY_X_ATTRIBUTE_COMPARISION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.WORKDAY_X_ATTRIBUTE_COMPARISION_MZ.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENTS_TERMED.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_SEC_LIMIT_CLS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.CLIENT_TENURE_DERIVED_MONTHLY_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_OFF_HOLD_CLIENTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_METRICS_W_BILLABLE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_METRICS_BY_SERVICE_LINE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_27_SEP_2023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE_DAILY_20231006.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY_2_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.NPS_CAREGIVER_SCORE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.ONHOLDCLIENTHISTORY_DATAFLEX.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.OVERTIME_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.PAYROLL_EMPLOYEE_DERIVED_MONTHLY_METRICS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.RPT_INVOICE_METRICS_BACKUP_051023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_WEEKLY_2_0_WIP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.UTILIZATION_WEEKLY_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.STEP_INCENTIVE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.REPORT.COVID_19_NEW_STARTS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPALLIANCE_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPALLIANCE_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPALLIANCE_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPALLIANCE_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPALLIANCE_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_DIM_EMPLOYEE_BCKP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_DIM_EMPLOYEE_BCKP_11102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPOPAL_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPOPAL_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPOPAL_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPOPAL_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_CAREGIVER_TOUCH_POINT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.AMERIHEALTH_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPANSWERCARE_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ADPOPAL_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_FACT_INTAKE_BKP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALLIANCE_DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ASR_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.AXXESS_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CCSI_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CCSI_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CCSI_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CENTENE_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CLEARCARE_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CLEARCARE_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.COSTALSYNCDATA_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.COSTALSYNCDATA_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.DATAFLEXSYNCDATA_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.DATAFLEXSYNCDATA_FACT_VISIT_HISTORY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.DOCEBO_FACT_DOCEBO_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MOLINA_FACT_GAPS_IN_CARE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_ACTIVITIES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ALAYACARE_DIM_CLIENT.sql
# ...
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MERCER_CENSUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MOLINA_DIM_CLIENT_BAKUP_02082023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.NAVISION_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.NAVISION_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.NAVISION_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.NAVISION_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.NAVISION_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OBP_FACT_SURVEY_RESPONSE_DETAIL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_BILLING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OLYMPUS_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_REFERRER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_CLIENT_SERVICE_BKCP2610.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_BILLING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_REFERRER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_CLIENT_SERVICE_BKCP2610.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_DIM_APPLICANT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_DIM_JOB.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_STATUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_STATUS_TEST.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_STATUS_TEST_2.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_WITH_PDR_STATUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYLOCITY_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYLOCITY_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYOR_CONTRACT_UI_DIM_PARENT_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYOR_CONTRACT_UI_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYOR_CONTRACT_UI_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_BILLING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_REFERRER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_SERVICES_1_0.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUALTRICS_DIM_DISTRIBUTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUALTRICS_FACT_SURVEY_OPTOUT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUICKBOOKS_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ROSTER_FACT_CLIENT_STATUS_HISTORY.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_CLIENT_BKCP_07_27_2023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_DATE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_SOURCE_SYSTEM.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_SUPERVISOR.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_CASH_INFLOW.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_EVV_VISIT_EXCEPTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.TRUSTPOINTDATA_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.TRUSTPOINTDATA_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.VIVENTIUM_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.VIVENTIUM_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.VIVENTIUM_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_DIM_EMPLOYEE_20241901.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_FACT_APPLICANT_STATUS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ZENDESK_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ZENDESK_FACT_CALLS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ZENDESK_FACT_SLA.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.AXXESS_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.CLEARCARE_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.COSTALSYNCDATA_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.COSTALSYNCDATA_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.DATAFLEXSYNCDATA_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EDISON_DIM_BILLING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EDISON_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EDISON_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EDISON_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EMPEONEDISON_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.FACT_SURVEY_RESPONSE_DETAIL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.GATOR_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.GATOR_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_DIM_PARTNER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.MATRIXCARE_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OBP_DIM_SURVEY_RESPONSE_HEADER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_CLIENT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_DIM_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OPENSYSTEMS_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.OSHAH_FACT_VISIT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_STATUS_BKP.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PARADOX_FACT_APPLICANT_STATUS_TEST_2023_10_04.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYLOCITY_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYLOCITY_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYLOCITY_FACT_PAYROLL_DETAILS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PAYOR_CONTRACT_UI_DIM_PARTNER_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_CONTRACT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_INTAKE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_PAYROLL_ABSENCE_GROUP_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_REVENUE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_PHYSICAL_OFFICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUALTRICS_FACT_DISTRIBUTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUICKBOOKS_DIM_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUICKBOOKS_DIM_EMPLOYEE_BKCP_11102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUICKBOOKS_DIM_PAYCODE_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.QUICKBOOKS_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_REFERRER.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_ADMISSION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_CLIENT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_INVOICE_TRACKING.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_FACT_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.SANDATAIMPORT_ORPHAN_BRANCH.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.TRUSTPOINTDATA_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.TRUSTPOINTDATA_FACT_PAYROLL.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_DIM_APPLICANT.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_DIM_EMPLOYEE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.WORKDAY_DIM_EMPLOYEE_BKCP_11102023.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_SERVICES.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.ZENDESK_FACT_TICKET.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.EDISON_DIM_VISIT_EXCEPTION.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.PREFERRED_DIM_INVOICE.sql
# Generated SQL file: SQL_Files\Table/DW_PROD.STAGE.TRUSTPOINTDATA_DIM_PAYCODE_MAPPING.sql

# %%
# this is my code 
import os
import re
import time  # Import the time module

# Get the current time in microseconds before starting execution
start_time = time.perf_counter()

# Get the current time in microseconds after finishing execution
end_time = time.perf_counter()

# Calculate the elapsed time in microseconds
elapsed_time_microseconds = (end_time - start_time) * 1e6  # Convert to microseconds

# Print the elapsed time in microseconds
print(f"Elapsed time: {elapsed_time_microseconds:.2f} microseconds")

# Get the current working directory
current_directory = os.getcwd()

# Specify the relative folder path containing .sql files
relative_folder_path = 'SQL_Files/Table'

# Combine the current working directory with the relative folder path
folder_path = os.path.join(current_directory, relative_folder_path)

sql_contents_list = []

try:
    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Filter out only the .sql files
    sql_files = [file for file in files if file.endswith('.sql')]

    # Read the contents of each .sql file and store them in a list
    for sql_file in sql_files:
        file_path = os.path.join(folder_path, sql_file)
        with open(file_path, 'r') as file:
            sql_contents = file.read()
            sql_contents_list.append(sql_contents)

except FileNotFoundError:
    print(f"Folder not found: {folder_path}")

except Exception as e:
    print(f"An error occurred: {e}")

# This code removes double quotes outside of DDL, including Database, schema, table name
def remove_outer_quotes(sql):
    ls1 = sql.split("(")[0].replace('"', '')
    ls2 = ["(" + i for i in sql.split("(")[1:]]
    ls2.insert(0, ls1)
    sql = "".join(ls2)

    return sql

# resource_database_name = []
# resource_schema_name = []
# resource_table = []
# print(resource_database_name)

# for i in resource_database_name:
#     print(i)
    
def check_table_comment(sql):
    comment_match = re.search(r"comment\s*=\s*'([^']*)'", sql, re.IGNORECASE)
    
    # Assuming 'command' contains your SQL command as a string
    command = sql.strip().upper()
    create_commands = re.findall(r"CREATE(?:\s+OR\s+REPLACE)?\s+TABLE(.*?)\(", command, re.DOTALL)
    # Iterate over each match in the list

    for create_command in create_commands:
        # Perform the split operation on each matched string
        database_info = create_command.strip().split('.')

        # Extract database name, schema name, and table name
        database_name = database_info[0].replace('"', '')
        schema_name = database_info[1].replace('"', '')
        table_name = database_info[2].replace('"', '')
        
        from datetime import datetime

        current_date = datetime.now().date()

        current_date = datetime.now().strftime("%Y-%m-%d")
        
        dynamic_db = ''
        dynamic__main_db = ''
        if database_name.endswith("_DEV"):
            dynamic_db += database_name.replace("_DEV", "_${var.SF_ENVIRONMENT}")
            dynamic__main_db += database_name.replace("_DEV", "")
        elif database_name.endswith("_PROD"):
            dynamic_db += database_name.replace("_PROD", "_${var.SF_ENVIRONMENT}")
            dynamic__main_db += database_name.replace("_PROD", "")

            
        purpose_value = ''
        if 'DISC'==dynamic__main_db:
            purpose = 'Discovery Data Population'
            purpose_value+=purpose
        elif 'DW'==dynamic__main_db and ('HAH'==schema_name or 'STAGE'==schema_name):
            purpose = 'Business Data Population'
            purpose_value+=purpose
        elif 'DW'==dynamic__main_db and 'INTEGRATION'==schema_name :
            purpose = 'Business Integration Data Population'
            purpose_value+=purpose
        elif 'DW'==dynamic__main_db and 'REPORT'==schema_name :
            purpose = 'Business Report Data Population'
            purpose_value+=purpose
        elif 'APP_DB'==dynamic__main_db:
            purpose = 'APP_DB Data Population'
            purpose_value+=purpose
        elif 'APP_DB'==dynamic__main_db:
            purpose = 'APP_DB Data Population'
            purpose_value+=purpose
        elif 'ETL_Management'==dynamic__main_db and 'AUDIT'==schema_name :
            purpose = 'ETL Audit Data Population'
            purpose_value+=purpose
        elif 'ETL_Management'==dynamic__main_db and 'CONFIG'==schema_name :
            purpose = 'ETL CONFIG Data Population'
            purpose_value+=purpose
        elif 'DEDUPE'==dynamic__main_db :
            purpose = 'Dedupe Data Population'
            purpose_value+=purpose
            
        if comment_match:
            comment = comment_match.group(1)
            return comment
        else:
            comment  = f''' 
    --*****************************************************************************************************************************

    -- NAME :  {database_name}.{schema_name}.{table_name}

    -- Purpose : {purpose_value}

    -- Project : {schema_name}

    -- Source Data update Frequency : 60 min

    --

    -- DEVELOPMENT LOG:

    -- DATE        AUTHOR                NOTES:

    -- ----------  -------------------   -----------------------------------------------------------------------------------------------

    -- {current_date}  Terraform            Initial Development(from Terraform GitHub Action Deployment)

    --*****************************************************************************************************************************
            '''
            return comment


resource_table_name_list = []




# Main Python code
def python_terraform(sql, comment):
    comment = check_table_comment(sql)
    

       
    code = ""
    ddl = sql.split(';')

    for command in ddl:
        command = command.strip().upper()
        create_commands = re.findall(r"CREATE(?:\s+OR\s+REPLACE)?\s+TABLE(.*?)\(", command, re.DOTALL)

        # Get the database name, schema name, table name
        for create_command in create_commands:
            create_command = create_command.strip()
            database_info = create_command.split()[0].split('.')
            database_name = database_info[0].replace('"', '')
            schema_name = database_info[1].replace('"', '')
            table_name = database_info[2].replace('"', '')

#                 global resource_table_name
            # resource_database_name.append(database_name)
            # resource_schema_name.append(schema_name)
            # resource_table.append(table_name)


            # data_retention_time_in_days_schema = 1

            # Set the dynamic database name / remove dev, prod name
            dynamic_db = ''
            dynamic__main_db = ''
            if database_name.endswith("_DEV"):
                dynamic_db += database_name.replace("_DEV", "_${var.SF_ENVIRONMENT}")
                dynamic__main_db += database_name.replace("_DEV", "")
            elif database_name.endswith("_PROD"):
                dynamic_db += database_name.replace("_PROD", "_${var.SF_ENVIRONMENT}")
                dynamic__main_db += database_name.replace("_PROD", "")



            # Create table
            resource_table_name = f"resource \"snowflake_table\" \"{dynamic__main_db}_{schema_name}_{table_name}\""
            code += f"{resource_table_name} {{\n"
            code += f"\tdatabase = \"{dynamic_db}\"\n"

            resource_table_name_demo = f'{dynamic__main_db}_{schema_name}_{table_name}'
            resource_table_name_list.append(resource_table_name_demo)

            code += f"\tschema = \"{schema_name}\"\n"
            code += f"\tname = \"{table_name}\"\n"
            # code += f"\tdata_retention_days = {data_retention_time_in_days_schema}\n"
            code += f"\tchange_tracking = false\n"
            code += f"\tcomment = \"{comment}\"\n"

            # Find the column names
            column_matches = re.findall(
                r'"([^"]+)"|([a-zA-Z_][\w\s/\-*^]*)\s+(?:AS\s+)?(?:(?:VARCHAR|CHAR|NUMBER|BINARY|STRING|TIMESTAMP_NTZ|TIMESTAMP_TZ|TIMESTAMP|TIME|ARRAY|VARIANT|OBJECT|TIMESTAMP_LTZ|GEOGRAPHY|GEOMETRY|BLOB|CLOB|TINYINT|DECIMAL)\([\d,]+\)|ARRAY|VARCHAR|TIMESTAMP_NTZ|TIMESTAMP_TZ|TIMESTAMP|BOOLEAN|TEXT|DATE|INT|INTEGER|FLOAT|VARIANT|OBJECT|TIMESTAMP_LTZ|GEOGRAPHY|GEOMETRY|BLOB|CLOB|TINYINT|DECIMAL)',
                sql.replace('\n', ' '))
            column_names = [column[0] or column[1] for column in column_matches if column[0] or column[1]]
            column_names = [column.strip() for column in column_names if column.strip() != 'AS']

            # Find the Not Null column names
            not_null_pattern = r'(?:"(.*?)".*?NOT NULL|(\w+)\s+.*?NOT NULL)'
            matches = re.findall(not_null_pattern, sql)
            not_null_columns = [match[0] or match[1] for match in matches]

            # Find the Comment column names
            Comment_pattern = r'(?:"(.*?)".*?COMMENT\s+\'(.*?)\'|(\w+)\s+.*?COMMENT\s+\'(.*?)\')'
            matches = re.findall(Comment_pattern, sql)
            comment_columns = [match[0] or match[2] for match in matches]
            comment_values = [match[1] or match[3] for match in matches]

            # Find generated_always_as in columns
            generated_pattern = r'(?:\"(.*?)\"|\b(\w+)\b).*?(?<=AS\s)\((.*?)\)\s*(?:(?=COMMENT)|(?=NOT\s+NULL)|(?=,|$))'
            generated_always_as = re.findall(generated_pattern, sql, re.MULTILINE)

            # Find DEFAULT values in columns
            DEFAULT_pattern = r'(?:\"(.*?)\"|\b(\w+)\b).*?(?<=DEFAULT\s)([^,\n]*?)(?=\s+(?:COMMENT|NOT\s+NULL|,\s*$))'
            DEFAULT_matches = re.findall(DEFAULT_pattern, sql, re.MULTILINE | re.IGNORECASE)

            # Find Check constraints in columns
            pattern_check = r'(?:\"(.*?)\"|\b(\w+)\b)\s+.*?CHECK\s+\((.*?)\)\s*(?:(?:COMMENT|NOT\s+NULL|,\s*$))'
            check_matches = re.findall(pattern_check, sql)

            # Find the data types
            data_type_matches = re.findall(
                r'("([^"]+)"|([\w\s/*&^?!-]+))\s+((?:VARCHAR|CHAR|NUMBER|BINARY|STRING|TIMESTAMP_NTZ|TIMESTAMP_TZ|TIMESTAMP|TIME|BOOLEAN|TEXT|DATE|INT|INTEGER|FLOAT|VARIANT|ARRAY|OBJECT|TIMESTAMP_LTZ|GEOGRAPHY|GEOMETRY|BLOB|CLOB|TINYINT|DECIMAL)(?:\([\d,]+\))?)',
                sql.replace('\n', ' '))

            column_name_list = []
            data_types_list = []
            for match in data_type_matches:
                full_match, quoted_column_name, unquoted_column_name, data_type = match
                column_name = quoted_column_name or unquoted_column_name
                column_name = column_name.strip()
                data_type = data_type.strip()
                column_name_list.append(column_name)
                data_types_list.append(data_type)

            # Generate Terraform code for each column
            for col, j in zip(column_names, data_types_list):
                code += f"\ncolumn {{\n"
                code += f"\tname = \"{col}\"\n"
                code += f"\ttype = \"{j}\"\n"

                # Handle generated_always_as column
                for quoted_column, unquoted_column, expression in generated_always_as:
                    generated_column_name = quoted_column.strip() if quoted_column else unquoted_column.strip()
                    expression_cleaned = expression.strip()

                    if col == generated_column_name:
                        code += f"\tgenerated_always_as  = \"{expression_cleaned}\"\n"

                # Handle Default column
                for match_def in DEFAULT_matches:
                    DEFAULT_column_name = match_def[0] if match_def[0] else match_def[1]
                    DEFAULT_default_value = match_def[2]
                    DEFAULT_column_name = DEFAULT_column_name.replace('"', '').strip()
                    DEFAULT_default_value = DEFAULT_default_value.replace('"', '').replace("'", '').strip()

                    if col == DEFAULT_column_name:
                        code += f"\tdefault = \"{DEFAULT_default_value}\"\n"

                # Handle Check column
                for check_match in check_matches:
                    check_column_name = check_match[0] or check_match[1]
                    check_condition = check_match[2]
                    if col == check_column_name:
                        code += f"\tcheck {{\n"
                        code += f"\tcondition = \"{check_condition}\"\n"
                        code += "}\t\n"

                # Handle Not Null column
                if col in not_null_columns:
                    code += f"\tnullable = false\n"
                else:
                    code += f"\tnullable = true\n"

                # Handle Comment column
                for comm_col, comm_values in zip(comment_columns, comment_values):
                    if comm_col == col:
                        code += f"\tcomment = \"{comm_values}\"\n"

                code += "}\n\n"

            code += "}\n\n"
    return code

for sql_contents in sql_contents_list:
    sql_without_quotes = remove_outer_quotes(sql_contents)
    comment = check_table_comment(sql_without_quotes)  # Get the comment for the SQL content
    main = python_terraform(sql_without_quotes, comment)  # Call python_terraform with both sql and comment
    # Extract database name and schema name from the SQL content
    extract_schema_database_table = re.search(r'\b(\w+)\.(\w+)\.(\w+)', sql_without_quotes)
    if extract_schema_database_table:
        database_name, schema_name, table_name = extract_schema_database_table.groups()

        # Update the output folder path to include database name and schema name
        output_folder = os.path.join(current_directory, 'Terraform_Files', database_name, schema_name, 'Table')

        try:
            os.makedirs(output_folder, exist_ok=True)
        except Exception as e:
            print(f"An error occurred while creating the output folder: {e}")

#         Write Terraform code to the appropriate output file
        try:
            dynamic_db = ''
            dynamic__main_db = ''
            if database_name.endswith("_DEV"):
                dynamic_db += database_name.replace("_DEV", "_${var.SF_ENVIRONMENT}")
                dynamic__main_db += database_name.replace("_DEV", "")
            elif database_name.endswith("_PROD"):
                dynamic_db += database_name.replace("_PROD", "_${var.SF_ENVIRONMENT}")
                dynamic__main_db += database_name.replace("_PROD", "")

            resource_table_name = f"{dynamic__main_db}_{schema_name}_{table_name}"
            output_filename = os.path.join(output_folder, f"{resource_table_name}.tf")

            with open(output_filename, 'w') as tf_file:
                tf_file.write(main)
        except Exception as e:
            print(f"An error occurred while writing the output file: {e}")
    else:
        print("Unable to extract database name and schema name from the SQL content.")
# Out:
# Elapsed time: 33.00 microseconds
