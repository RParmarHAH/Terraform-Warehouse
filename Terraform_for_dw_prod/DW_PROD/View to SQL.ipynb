# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import os
import snowflake.connector

# Replace these with your Snowflake account credentials and connection details
account = ''  # Replace with your Snowflake account URL
warehouse = 'DEMO_WH'
database = 'DW_PROD'
schema = 'list_schema'
username = ''  # Replace with your Snowflake username
password = ''  # Replace with your Snowflake password

# Create the SQL_Files and View folders
sql_files_dir = "SQL_Files"
view_dir = os.path.join(sql_files_dir, "View")

if not os.path.exists(sql_files_dir):
    os.mkdir(sql_files_dir)

if not os.path.exists(view_dir):
    os.mkdir(view_dir)

# Establish a connection to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# Create a cursor to execute SQL queries
cursor = conn.cursor()

list_schema = ['ACROSS_DEDUPE','HAH','INTEGRATION','PUBLIC','REPORT','STAGE'] #add schemas

views = [] # keep this empty for now

# Execute the query to get the list of views
for schema in list_schema:
    
    # Query Snowflake to get a list of views in the specified database and schema
    view_query = f'''
    SELECT (table_catalog || '.' || table_schema || '.' || table_name) table_name
    FROM information_schema.views
    WHERE table_schema = '{schema}' AND table_catalog = '{database}'
    '''
    cursor.execute(view_query)
    # Fetch the results
    view = cursor.fetchall()
    views.extend(view)


# Close the cursor and connection when done with the view query
cursor.close()

if views:
    # Iterate through the views and retrieve DDL statements
    for view_info in views:
        view_name = view_info[0]

        # Construct the fully qualified view name
        fully_qualified_view_name = f'{view_name}'

        # Query to retrieve the DDL statement for the view
        ddl_query = f'''
            SELECT GET_DDL('VIEW', '{view_name}', true)
        '''

        # Create a new cursor for the DDL query
        cursor = conn.cursor()

        # Execute the DDL query
        cursor.execute(ddl_query)

        # Fetch the DDL statement
        ddl_statement = cursor.fetchone()[0]


        # Modify the DDL statement to include the database and schema names
        modified_ddl_statement = ddl_statement.replace(f'create or replace view {view_name}',
                                                       f'create or replace view {fully_qualified_view_name}')

        # Remove line breaks and extra spaces
        modified_ddl_statement = ddl_statement.replace('\r\n', '\n')

        # Step 2: Create a .sql file and write the DDL statement to it
        sql_file_name = f"{view_dir}/{fully_qualified_view_name}.sql"
        with open(sql_file_name, 'w') as sql_file:
            sql_file.write(modified_ddl_statement)

        # Step 3: Print the file name (database.schema.view name)
        print(f"Generated SQL file: {fully_qualified_view_name}")

        # Close the cursor for the DDL query
        cursor.close()
else:
    print(f"No views found in the specified schema '{schema}' in database '{database}'.")

# Close the connection
conn.close()
# Out:
# Generated SQL file: DW_PROD.HAH.VW_APPLICANT_DETAILS
# Generated SQL file: DW_PROD.HAH.VW_DIM_SOURCE_SYSTEM_TO_MARKET
# Generated SQL file: DW_PROD.HAH.CLONE_CURRENT_VIEW_DF_FACT_VISIT
# Generated SQL file: DW_PROD.HAH.DF_FACT_VISIT_09_26_22
# Generated SQL file: DW_PROD.HAH.VW_DIM_BRANCH_MERGED
# Generated SQL file: DW_PROD.HAH.VW_DIM_CLIENT_MERGED
# Generated SQL file: DW_PROD.HAH.VW_DIM_EMPLOYEE_MERGED_BACKUP_20210813
# Generated SQL file: DW_PROD.HAH.VW_FACT_BRANCH_PAYROLL_PERIODS_MERGED
# Generated SQL file: DW_PROD.HAH.VW_FACT_BUDGET_MERGED
# Generated SQL file: DW_PROD.HAH.VW_FACT_INTAKE_MERGED
# Generated SQL file: DW_PROD.INTEGRATION.GET_CROSSWALK_DATA
# Generated SQL file: DW_PROD.INTEGRATION.VW_ALL_EMPLOYEE_INPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_AMS_PAYROLL_MAPPING_INPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_CROSSWALK_INPUT_CLEANUP
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_EMPLOYEE_INPUT_QUERY
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_EMPLOYEE_INPUT_QUERY_BKP
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_CLIENT_AL
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_CLIENT_MERGED
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_CLIENT_NY
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_CLIENT_OH
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_AL
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_GA_SECOND
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_MERGED
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_NY
# Generated SQL file: DW_PROD.INTEGRATION.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_DIM_DATE
# Generated SQL file: DW_PROD.INTEGRATION.VW_JAZZHR_PARADOX_MASTER_LIST
# Generated SQL file: DW_PROD.INTEGRATION.VW_PROD_AMS_PAYROLL_MAPPING_INPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_WORKDAY_PARADOX_APPLICANT_MAPPING
# Generated SQL file: DW_PROD.INTEGRATION.WEEKLY_FALLOUT_PROJECTION_REPORT
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_CROSSWALK_OUTPUT_CLEANUP
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_CLIENT_GA
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_GA_FIRST
# Generated SQL file: DW_PROD.INTEGRATION.VW_DIM_EMPLOYEE_OH
# Generated SQL file: DW_PROD.INTEGRATION.VW_EMPLOYEE_CROSS_WALK
# Generated SQL file: DW_PROD.INTEGRATION.VW_EMPLOYEE_ENTERPRISE_ID_MERGED_SENT_TO_WD
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_CROSSWALK_INPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_APPLICANT_CROSSWALK_OUTPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_WORKDAY_CROSSWALK_DEDUPE_OUTPUT
# Generated SQL file: DW_PROD.INTEGRATION.VW_WORKDAY_CROSSWALK_DEDUPE_INPUT
# Generated SQL file: DW_PROD.PUBLIC.FIELD_ADMIN_METRICS
# Generated SQL file: DW_PROD.PUBLIC.MS_CON
# Generated SQL file: DW_PROD.PUBLIC.MT1
# Generated SQL file: DW_PROD.PUBLIC.VISIT_EMPLOYEES_HAVING_NULL_PAYROLL_IN_CROSSWALK
# Generated SQL file: DW_PROD.PUBLIC.VW_ACROSS_DEDUPE_CONFIG_FINAL
# Generated SQL file: DW_PROD.PUBLIC.VW_APPLICANT_EMPLOYEE_INPUT_QUERY_TEST
# Generated SQL file: DW_PROD.PUBLIC.VW_EMPLOYEE_CROSS_WALK_AMS_PAYROLL_APPLICANT_MAPPING
# Generated SQL file: DW_PROD.PUBLIC.VW_EMPLOYEE_CROSS_WALK_TEST
# Generated SQL file: DW_PROD.PUBLIC.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_TEST_DG
# Generated SQL file: DW_PROD.PUBLIC.WEEKLY_FALLOUT_PROJECTION_REPORT
# Generated SQL file: DW_PROD.PUBLIC.WORKDAY_EMPLOYEES_NOT_IN_CROSSWALK
# Generated SQL file: DW_PROD.PUBLIC.WORKDAY_BASE_VIEW
# Generated SQL file: DW_PROD.PUBLIC.VW_ALVAREZMARSALDATA
# Generated SQL file: DW_PROD.PUBLIC.VW_AXXESS_CLIENTS
# Generated SQL file: DW_PROD.PUBLIC.VW_CURRENT_CCSI_FACT_REVENUE
# Generated SQL file: DW_PROD.PUBLIC.VW_CURRENT_CCSI_FACT_VISIT
# Generated SQL file: DW_PROD.PUBLIC.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_STEP_INCENTIVE
# Generated SQL file: DW_PROD.PUBLIC.VW_PAYPERIOD_GROUP
# Generated SQL file: DW_PROD.PUBLIC.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_MV
# Generated SQL file: DW_PROD.REPORT.ALVAREZMARSALDATA_WORKEDHOURS
# Generated SQL file: DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_SEC_WITH_MASTER_CLIENT_KEY
# Generated SQL file: DW_PROD.REPORT.FIELD_ADMIN_METRICS
# Generated SQL file: DW_PROD.REPORT.LOST_CLIENTS_2020_21
# Generated SQL file: DW_PROD.REPORT.MS_OSHAH_CONTRACT_MAP
# Generated SQL file: DW_PROD.REPORT.ROLLING_ONHOLDCLIENTCOUNT_MONTHLY
# Generated SQL file: DW_PROD.REPORT.TURNOVER_BY_WAGE
# Generated SQL file: DW_PROD.REPORT.VW_CAREGIVERS_W_HRS_MISSING_IN_PAYROLL
# Generated SQL file: DW_PROD.REPORT.VW_CAREGIVER_BUDGET
# Generated SQL file: DW_PROD.REPORT.VW_CAREGIVER_BUDGET_22
# Generated SQL file: DW_PROD.REPORT.VW_CLIENTS_REFERRED_BY_REFERRAL_DATE_EXEC_OPS_MAPPING
# Generated SQL file: DW_PROD.REPORT.VW_CLIENTS_REFERRED_WIP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP_WIP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENT_CAREGIVER_RELATIONSHIP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENT_CENSUS
# Generated SQL file: DW_PROD.REPORT.VW_CONTRACT_DETAILS
# Generated SQL file: DW_PROD.REPORT.VW_CONTRACT_DETAILS_W_PCM
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_DERIVED_WEEKLY_VISIT_METRICS
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_HOURS_AND_CENSUS_BY_SERVICE_PAYROLL_PERIOD_DAILY
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_REFERRED
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_TERMED
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_1_0
# Generated SQL file: DW_PROD.REPORT.VW_GATOR_CAREGIVER_MAPPING
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CENSUS_BUDGETEDDATA_WEEKLY
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_WEEKLY
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENTS_REACTIVATED
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENTS_TERMED
# Generated SQL file: DW_PROD.REPORT.VW_PARADOX_APPLICATION_DETAILS
# Generated SQL file: DW_PROD.REPORT.ROLLING_ONHOLDCLIENTCOUNT_MDA
# Generated SQL file: DW_PROD.REPORT.VW_CARE_PROGRAM_MEMBERSHIP_STATUS_HISTORY
# Generated SQL file: DW_PROD.REPORT.VW_DASHBOARD_CONTRACTS
# Generated SQL file: DW_PROD.REPORT.VW_DAYFALL_CALC
# Generated SQL file: DW_PROD.REPORT.VW_DAYFALL_CALC_WIP
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_REACTIVATED
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_BCP
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_W_DEMOGRAPHICS
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_W_DEMOGRAPHICS_AND_ORIGINAL_BRANCH
# Generated SQL file: DW_PROD.REPORT.VW_GATOR_CAREGIVER_CARE_PROGRAM
# Generated SQL file: DW_PROD.REPORT.VW_GATOR_CLIENT_MAPPING
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CENCUS_BUDGETEDDATA
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_MONTHLY_CLONE_09282023
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_WEEKLY_EXEC_OPS
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_WEEKLY_EXEC_OPS_BCK_20231101
# Generated SQL file: DW_PROD.REPORT.VW_IDOA_CONTRACTS_UTILIZATION
# Generated SQL file: DW_PROD.REPORT.VW_INVOICES_METRICS
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENTS_REFERRED
# Generated SQL file: DW_PROD.REPORT.VW_PARADOX_APPLICATION_DETAILS_BACKUP_20221110
# Generated SQL file: DW_PROD.REPORT.VW_ROSTER_CARE_PROGRAM_MONTHLY_STATUS
# Generated SQL file: DW_PROD.REPORT.VW_SLA
# Generated SQL file: DW_PROD.REPORT.VW_WORKDAY_X_ATTRIBUTE_COMPARISION
# Generated SQL file: DW_PROD.REPORT.VW_DATAFLEX_GP_SANDATA_DISCREPENCIES
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_HOURS_AND_CENSUS_BY_SERVICE_PAYROLL_PERIOD_WEEKLY
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_CLONE_20230925
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_DIM_DATE_FOR_HOURS_AND_CLIENT_CENSUS_MONTHLY
# Generated SQL file: DW_PROD.REPORT.VW_GATOR_CLIENT_CARE_PROGRAM
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_MONTHLY
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_MONTHLY_WIP_NEW
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_UTILIZATION
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_WEEKLY_WIP_NEW
# Generated SQL file: DW_PROD.REPORT.VW_INVOICE_DETAIL_EXTRACT_FOR_FINANCE
# Generated SQL file: DW_PROD.REPORT.VW_PERFORMANCE_TO_BUDGET
# Generated SQL file: DW_PROD.REPORT.CLIENT_DERIVED_MONTHLY_VISIT_METRICS_SEC_WITH_MASTER_CLIENT_KEY_BKCP_08_01_2022
# Generated SQL file: DW_PROD.REPORT.CLIENT_METRICS_FOR_SLT_FJN_W_BILLABLE
# Generated SQL file: DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_METRICS_W_DEMOGRAPHICS
# Generated SQL file: DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_W_BILLABLE_MASTER_EMP_KEY
# Generated SQL file: DW_PROD.REPORT.ROLLING_ONHOLDCLIENTCOUNT
# Generated SQL file: DW_PROD.REPORT.ROLLING_ONHOLDCLIENTCOUNT_WEEKLY
# Generated SQL file: DW_PROD.REPORT.VW_BUDGET
# Generated SQL file: DW_PROD.REPORT.VW_CLIENTS_REFERRED_BY_REFERRAL_DATE_OPD_MAPPING_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENTS_REFERRED_BY_VISIT_DATE_OPD_MAPPING_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_CLIENT_METRICS_FOR_SEC
# Generated SQL file: DW_PROD.REPORT.VW_DAILYVISITANDCLIENTCOUNT
# Generated SQL file: DW_PROD.REPORT.VW_COVID_19_ON_HOLD_CLIENTS
# Generated SQL file: DW_PROD.REPORT.VW_EQUIFAX_EMPLOYEE
# Generated SQL file: DW_PROD.REPORT.VW_EQUIFAX_EMPLOYEE_PAYROLL
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_STARTED
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_STARTED_DIM_DATE
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_TERMED_DIM_DATE
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENT_CENSUS
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_OVERTIME
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_W_DEMOGRAPHICS_AND_ORIGINAL_BRANCH_BKCP_08_01_2022
# Generated SQL file: DW_PROD.REPORT.VW_FACT_EVV_VISIT_EXCEPTIONS_W_CANCELCODE
# Generated SQL file: DW_PROD.REPORT.VW_IDOA_REJECT_REPORT
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENT_CENSUS_OLD
# Generated SQL file: DW_PROD.REPORT.VW_REVENUE_FROM_MCOS
# Generated SQL file: DW_PROD.REPORT.CLIENT_METRICS_FOR_SLT_FJN
# Generated SQL file: DW_PROD.REPORT.ROLLING_ONHOLDCLIENTCOUNT_MONTHLY_MDA
# Generated SQL file: DW_PROD.REPORT.VW_ACTIVE_EMPLOYEES
# Generated SQL file: DW_PROD.REPORT.VW_COVID_19_OFF_HOLD_CLIENTS
# Generated SQL file: DW_PROD.REPORT.VW_COVID_19_ONHOLDASOFDATE_DATAFLEX
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_DERIVED_WEEKLY_METRICS_BY_SERVICE_LINE
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_SUPERVISOR_BY_SERVICE_MONTH
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_SUPERVISOR_BY_SERVICE_WEEK
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_CLIENTS_REACTIVATED_DIM_DATE
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_STEP_INCENTIVE
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_AUTHORIZATION_HOURS_DAILY
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_BKCP_08_01_2022
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_FOR_HH_VALIDATION_FJN
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_W_DEMOGRAPHICS_AND_ORIGINAL_BRANCH_VAI
# Generated SQL file: DW_PROD.REPORT.VW_HOURSDATA
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CENSUS_BUDGETEDDATA_DAILY
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CENSUS_OVERTIME_EXCLUDED_CONTRACTS
# Generated SQL file: DW_PROD.REPORT.VW_INDIANA_DISTINCTCLIENT_BY_ZIPCODE
# Generated SQL file: DW_PROD.REPORT.VW_LATEST_PERIOD_PAID_BY_BRANCH
# Generated SQL file: DW_PROD.REPORT.VW_NEXTONHOLDDATA_DATAFLEX
# Generated SQL file: DW_PROD.REPORT.VW_NEXTONHOLDDATA_SANDATA
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENTS_STARTED
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_DIM_DATE
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_OVERTIME_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_UTILIZATION_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_PARADOX_APPLICATION_DETAILS_WITH_PDR_STATUS
# Generated SQL file: DW_PROD.REPORT.VW_PAYPERIOD_GROUP
# Generated SQL file: DW_PROD.REPORT.VW_SANDATA_REJECT_CODES
# Generated SQL file: DW_PROD.REPORT.VW_EMPLOYEE_DERIVED_MONTHLY_METRICS_BY_SERVICE_LINE
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_HOURS_AND_CENSUS_BY_SERVICE_PAYROLL_PERIOD_DAILY_BKCP_08_01_2022
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CENSUS_BY_SERVICE_PAYROLL_PERIOD_DAILY
# Generated SQL file: DW_PROD.REPORT.VW_INVOICE_EXTRACT_FOR_FINANCE
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_CLIENT_CENSUS_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_OPS_PERFORMANCE_HOURS_AND_CENSUS_BY_SERVICE_PAYROLL_PERIOD_DAILY_BACKUP
# Generated SQL file: DW_PROD.REPORT.VW_PARADOX_APPLICATION_DETAILS_MO
# Generated SQL file: DW_PROD.REPORT.VW_REGION_BRANCH_KEY_MAPPING
# Generated SQL file: DW_PROD.REPORT.VW_REVENUE_BY_CONTRACT
# Generated SQL file: DW_PROD.REPORT.VW_RISKONNECT_EXTRACT
# Generated SQL file: DW_PROD.REPORT.VW_SLT_DASHBOARD_SCHEDULED_HOURS_DAILY
# Generated SQL file: DW_PROD.REPORT.VW_EXECUTIVE_OPERATIONS_EXCELLENCE_UTILIZATION_DIM_DATE
# Generated SQL file: DW_PROD.REPORT.VW_HOURS_AND_CLIENT_CENSUS_WEEKLY_EXEC_OPS_FOR_LAINE
# Generated SQL file: DW_PROD.STAGE.SANDATAIMPORT_DIM_CONTRACT_TEMP_VIEW
# Generated SQL file: DW_PROD.STAGE.SANDATAIMPORT_DIM_INVOICE_TEMP_VIEW
# Generated SQL file: DW_PROD.STAGE.SANDATAIMPORT_FACT_INTAKE_TEMP_VIEW
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_FACT_BRANCH_PAYROLL_PERIODS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_FACT_CLIENT_SERVICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_FACT_CLIENT_SERVICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.SANDATAIMPORT_FACT_REVENUE_TEMP_VIEW
# Generated SQL file: DW_PROD.STAGE.SANDATAIMPORT_FACT_VISIT_TEMP_VIEW
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_HAH_REPORTING_FACT_WRITEOFF
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_SERVICES_1_0
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_SERVICES_1_0
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_VISIT_EXCEPTION
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_GPSYNCDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_HAH_REPORTING_FACT_WRITEOFF
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_UPD_VISIT_STATUS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.MI_DF_VISIT_CLAIMS
# Generated SQL file: DW_PROD.STAGE.ORPHAN_CHECK
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_ALAYACARE_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_INVOICE_CREDITS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_GPSYNCDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_FACT_EVV_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_GPSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_PAYLOCITY_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_FACT_EVV_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DATAFLEXSYNCDATA_FACT_INVOICE_CREDITS
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_DIM_INVOICE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_COSTALSYNCDATA_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_INTAKE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_GPSYNCDATA_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_TRUSTPOINTDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_SANDATAIMPORT_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_CCSI_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_COSTALSYNCDATA_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_DIM_CLIENT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_FACT_VISIT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_SANDATAIMPORT_DIM_EMPLOYEE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_BRANCH
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_CONTRACT
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_SERVICES
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_TRUSTPOINTDATA_FACT_PAYROLL
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_DATAFLEXSYNCDATA_FACT_REVENUE
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_DELETED_MATRIXCARE_DIM_SERVICES
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_MATRIXCARE_DIM_SUPERVISOR
# Generated SQL file: DW_PROD.STAGE.VW_CURRENT_PAYLOCITY_FACT_PAYROLL
