# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import os
import snowflake.connector

# Replace these with your Snowflake account credentials and connection details
account = ''  # Replace with your Snowflake account URL
warehouse = 'DEMO_WH'
database = 'DW_PROD'
schema = 'schemas'
username = ''  # Replace with your Snowflake username
password = ''  # Replace with your Snowflake password

#  Create the SQL_Files and Procedure folders
sql_files_dir = "SQL_Files"
procedure_dir = os.path.join(sql_files_dir, "stored procedure")
#procedure_dir = "stored procedure"
if not os.path.exists(sql_files_dir):
    os.mkdir(sql_files_dir)

if not os.path.exists(procedure_dir):
    os.mkdir(procedure_dir)

# Establish a connection to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema,
    role='SYSADMIN'
)

# Create a cursor to execute SQL queries
cursor = conn.cursor()
schemas = ['ACROSS_DEDUPE','HAH','INTEGRATION','PUBLIC','REPORT','STAGE']


# Query Snowflake to get a list of procedures in the specified database and schema


procedures = []
for schema in schemas:
# Execute the query to get the list of procedures
    procedure_query = f'''
    SELECT (procedure_catalog || '.' || procedure_schema || '.' || procedure_name) procedure_name, ARGUMENT_SIGNATURE
    FROM information_schema.procedures
    WHERE procedure_schema = '{schema}' AND procedure_catalog = '{database}'
    '''
    cursor.execute(procedure_query)
    procedure = cursor.fetchall()
    procedures.extend(procedure)
    

# Close the cursor and connection when done with the procedure query
cursor.close()

#
def extract_type(ip_string):
    ip_string_trimmed = ip_string.replace('(','').replace(')','')
    elements = [element.strip() for element in ip_string_trimmed.split(',')]
    dtypes = [element.split()[-1] for element in elements]
    result = ','.join(dtypes)
    return result

if procedures:
    # Iterate through the procedures and retrieve DDL statements
    for procedure_info in procedures:
        procedure_name = procedure_info[0]
        if '()' not in procedure_info[1]:
            procedure_details = extract_type(procedure_info[1])
            #print(procedure_details, '\n')
            ddl_query = f'''SELECT GET_DDL('PROCEDURE', '{procedure_name}({procedure_details})',true)'''
            #print(ddl_query, '\n')
        else:
            ddl_query = f'''SELECT GET_DDL('PROCEDURE', '{procedure_name}()',true)'''
            #print(ddl_query, '\n')

        # Construct the fully qualified procedure name
        fully_qualified_procedure_name = f'{procedure_name}'
        try:
            # Query to retrieve the DDL statement for the procedure

            # Create a new cursor for the DDL query
            cursor = conn.cursor()

            # Execute the DDL query
            cursor.execute(ddl_query)

            # Fetch the DDL statement
            ddl_statement = cursor.fetchone()[0]

            # Modify the DDL statement to include the database and schema names
            modified_ddl_statement = ddl_statement.replace(f'CREATE OR REPLACE PROCEDURE "{procedure_name}"',
                                                          f'CREATE OR REPLACE PROCEDURE {fully_qualified_procedure_name}')

            # Remove line breaks and extra spaces
            modified_ddl_statement = modified_ddl_statement.replace('\r\n', '\n').replace('\xa0', ' ').replace('\u2003', ' ')
        
            # Step 2: Create a .sql file and write the DDL statement to it
            sql_file_name = f"{procedure_dir}/{fully_qualified_procedure_name}.sql"
            with open(sql_file_name, 'w') as sql_file:
                sql_file.write(modified_ddl_statement.encode("utf-8").decode("utf-8"))

            # Step 3: Print the file name (database.schema.procedure name)
            print(f"Generated SQL file: ", sql_file_name)

            # Close the cursor for the DDL query
            cursor.close()
        except snowflake.connector.errors.ProgrammingError as e:
            print('Procedure does not exist or not authorized ', fully_qualified_procedure_name)
else:
    print(f"No procedures found in the specified schema '{schema}' in database '{database}'.")

# Close the connection
conn.close()
# Out:
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPANSWERCARE_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPOPAL_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COSTALSYNCDATA_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PAYLOCITY_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_GATOR_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OLYMPUS_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_TRUSTPOINTDATA_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.FACT_EMPLOYEE_ACQUIRED_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_AXXESS_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_INTAKE_BKP_BFR_AUTH_08082022.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPANSWERCARE_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPOPAL_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AXXESS_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_TRUSTPOINTDATA_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPOPAL_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALLIANCE_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AMERIHEALTH_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EMPEONEDISON_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_GPSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PAYLOCITY_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_TRUSTPOINTDATA_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALLIANCE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COSTALSYNCDATA_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_GPSYNCDATA_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MOLINA_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COASTALGP_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_GPSYNCDATA_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ADPALLIANCE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CS_FACT_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EMPEONEDISON_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_JAZZHR_DIM_JOB.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PAYLOCITY_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_QUALTRICS_FACT_SURVEY_OPTOUT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_VIVENTIUM_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.FACT_CLIENT_ACQUIRED_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_ACTIVITIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_GPSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.X_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EMPEONPREFERRED_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_QUICKBOOKS_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CS_FACT_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DOCEBO_FACT_DOCEBO_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONPREFERRED_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_JAZZHR_DIM_APPLICANT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_FACT_VISIT_MV_PREVIOUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ROSTER_FACT_CLIENT_STATUS_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALLIANCE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AXXESS_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CENTENE_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_FACT_INVOICE_CREDITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_HM_FACT_SURVEY_RESPONSE_DETAIL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MOLINA_DIM_CLIENT_BAKUP_02082023.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PREFERRED_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_GPSYNCDATA_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPALLIANCE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPANSWERCARE_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPANSWERCARE_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COSTALSYNCDATA_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPANSWERCARE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COSTALSYNCDATA_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_FACT_APPLICANT_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_NAVISION_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_TRUSTPOINTDATA_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ZENDESK_FACT_CALLS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_FACT_INVOICE_TRACKING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DIM_DATE_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_REPORT_NPS_CAREGIVER_SCORE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PARADOX_FACT_APPLICANT_WITH_PDR_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_VIVENTIUM_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_DIM_ACTIVITIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AXXESS_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COSTALSYNCDATA_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_BILL_PERSON.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EMPEONPREFERRED_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PARADOX_DIM_JOB.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_VIVENTIUM_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONEDISON_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PAYLOCITY_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_QUICKBOOKS_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPALLIANCE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COSTALSYNCDATA_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_JAZZHR_DIM_JOB.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_NAVISION_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OLYMPUS_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ROSTER_FACT_CLIENT_STATUS_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_FACT_VISIT_BKCP_0525.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PARADOX_FACT_APPLICANT_WITH_PDR_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EMPEONEDISON_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_GPSYNCDATA_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_GPSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PAYOR_CONTRACT_UI_DIM_PARENT_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PAYOR_CONTRACT_UI_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PAYOR_CONTRACT_UI_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_FACT_EVV_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_WORKDAY_FACT_APPLICANT_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DIM_EMPLOYEE_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ADPOPAL_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_FACT_CLIENT_SERVICE_BKCP2610.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_AXXESS_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_AXXESS_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COASTALGP_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EDISON_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_VIVENTIUM_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALLIANCE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COSTALSYNCDATA_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EDISON_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_QUICKBOOKS_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_QUICKBOOKS_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_BRANCH_20221121_RSUTHAR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AXXESS_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PAYLOCITY_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_QUICKBOOKS_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_AXXESS_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONEDISON_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONEDISON_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PAYOR_CONTRACT_UI_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MDM_DIM_EMPLOYEE_TP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_AXXESS_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_JAZZHR_FACT_APPLICANT_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPOPAL_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ADPALLIANCE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_DIM_SERVICES_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CCSI_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COSTALSYNCDATA_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_COSTALSYNCDATA_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_NAVISION_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_PARTNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_JAZZHR_DIM_APPLICANT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_MATRIXCARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CLEARCARE_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ADPALLIANCE_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ADPANSWERCARE_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_FACT_VISIT_CSF.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CENTENE_DIM_CLIENT_BAKUP_02082023.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_CLIENT_SERVICE_BKCP1310.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_NAVISION_DIM_PAYCODE_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OSHAH_FACT_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALLIANCE_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COASTALGP_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COSTALSYNCDATA_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MOLINA_GAPS_IN_CARE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_QUALTRICS_FACT_DISTRIBUTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CCSI_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_COSTALSYNCDATA_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONPREFERRED_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_MATRIXCARE_FACT_VISIT_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PAYOR_CONTRACT_UI_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_SANDATAIMPORT_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_TRUSTPOINTDATA_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ADPOPAL_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_DIM_REFERRER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CCSI_FACT_INTAKE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_DATAFLEXSYNCDATA_DIM_SUPERVISOR.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EMPEONPREFERRED_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_NAVISION_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OPENSYSTEMS_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_FACT_PARTNER_CONTRACT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_PREFERRED_DIM_PARTNER_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_TRUSTPOINTDATA_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_WORKDAY_FACT_APPLICANT_STATUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_EMPEONPREFERRED_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_PREFERRED_DIM_BILLING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_COASTALGP_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_OSHAH_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_QUALTRICS_FACT_SURVEY_OPTOUT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_SANDATAIMPORT_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_WORKDAY_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EMPEONEDISON_DIM_EMPLOYEE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_MATRIXCARE_DIM_ACTIVITIES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_VIVENTIUM_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_INVOICE_TRANSACTION_TYPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_FACT_CLIENT_SERVICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_CS_FACT_SURVEY_RESPONSE_DETAIL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ASR_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_EDISON_DIM_SERVICES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_PREFERRED_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_AXXESS_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALLIANCE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ALAYACARE_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_DATAFLEXSYNCDATA_FACT_ADMISSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_HM_FACT_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_DIM_VISIT_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OPENSYSTEMS_FACT_INVOICE_TRANSACTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_QUALTRICS_DIM_DISTRIBUTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_ROSTER_FACT_CLIENT_STATUS_HISTORY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_WORKDAY_DIM_APPLICANT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DIM_CONTRACT_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.FACT_VISIT_CONTRACT_UPDATE_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_FACT_BRANCH_PAYROLL_PERIODS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ASR_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_CLEARCARE_DIM_INVOICE_STATUS_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DATAFLEXSYNCDATA_DIM_CONTRACT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_DIM_SURVEY_RESPONSE_HEADER_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_FACT_SURVEY_QUESTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_LANDING_8X8_FACT_CALLS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_OPENSYSTEMS_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_QUICKBOOKS_FACT_PAYROLL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ALAYACARE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_ASR_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_CLEARCARE_FACT_REVENUE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.MERGE_STAGE_EMPEONPREFERRED_FACT_PAYROLL_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_OSHAH_DIM_VISIT_EXCEPTION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.DELETE_STAGE_SANDATAIMPORT_DIM_INVOICE_VISIT_LINKAGE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALAYACARE_DIM_CLIENT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_DIM_BRANCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.HAH.GET_STAGE_ALLIANCE_FACT_PARTNER_CONTRACT_SERVICE.sql
# ...
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.WORKDAY_CROSSWALK_DEDUPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.DATAFLEXSYNCDATA_MATRIXCARE_EMPLOYEE_MAPPING_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.DIM_PARTNER_CONTRACT_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.FACT_PAYROLL_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.FACT_VISIT_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_CLIENT_CROSS_WALK.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_DIM_CLIENT_MATCH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_MASTER_DIM_CLIENT_MS_MERGED_DEDUPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_MASTER_JAZZHR_PARADOX_MASTER_LIST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.SP_WORKDAY_X_ATTRIBUTE_COMPARISION_TABLE_REFRESH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_MASTER_FACT_AMS_PAYROLL_PA_MAPPING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_DIM_EMPLOYEE_MATCH_CCSI_DFLEX_IL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.INTEGRATION.GET_MASTER_DIM_EMPLOYEE_DE_MERGED_DEDUPE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_REPORT_ONHOLDCLIENTHISTORY_DATAFLEX.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_ASR_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.UPDATE_EMPLOYEE_CROSS_WALK_HOURLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_REPORT_UTILIZATION_PROD_MV.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_EVV_VISIT_DEV.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.BACKUP_DW_PROD_SP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_ALAYACARE_FACT_VISIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_CCSI_DIM_INVOICE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_VISIT_MV.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.DATAFLEXSYNCDATA_MATRIXCARE_EMPLOYEE_MAPPING_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_MASTER_FACT_EMPLOYEE_CROSS_WALK.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_REPORT_EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_W_BILLABLE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_EMPLOYEE_KEYRING_DATA.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_MASTER_FACT_EMPLOYEE_CROSS_WALK_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_VISIT_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_REPORT_EMPLOYEE_DERIVED_WEEKLY_VISIT_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_VISIT_TEST2.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.FACT_EMPLOYEE_ACQUIRED_MERGED_POSTPROCESSING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_EVV_VISIT_EXCEPTIONS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_SANDATAIMPORT_FACT_INTAKE_MV_COMP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.PUBLIC.GET_STAGE_JAZZHR_DIM_APPLICANT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.EMPLOYEE_DERIVED_MONTHLY_METRICS_BY_SERVICE_LINE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CGR_OBS_SURVEY_RESPONSES_CC.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REFERRED_BACKUP_20210913.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_NPS_CLIENT_SCORE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_MONTHLY_METRICS_BY_SERVICE_LINE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ONHOLDCLIENTHISTORY_DATAFLEX.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CGR_OBS_SURVEY_RESPONSES_CC.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_SCHEDULE_METRICS_WEEKLY_BKCP_0525.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ACCOUNTS_RECEIVABLE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_RPT_AUTH_METRICS_BKP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_DAILY_BACKUP_20210913.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CLIENT_CENSUS_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CALL_TICKET.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_SCHEDULE_METRICS_MONTHLY_BKCP_0525.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_DERIVED_MONTHLY_VISIT_METRICS_SEC.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_SUPERVISOR_BY_SERVICE_WEEK.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_RPT_INVOICE_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_BACKUP_20210913.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_PAYROLL_EMPLOYEE_DERIVED_MONTHLY_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CAREGIVER_LINEAR_RETENTION_MONTHLY_INNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_TENURE_DERIVED_MONTHLY_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_OVERTIME_2.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_COUNT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_OVERTIME_HOURS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_TAKING_MONTHLY_SNAPSHOT_FOR_RCM_TABLES.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.PROC_MERGEONHOLDCLIENTHISTORY_DATAFLEX.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ADMIN_EXIT_SURVEY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REFERRED.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_METRICS_W_BILLABLE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_PBITEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_WEEKLY_2_0_WIP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CAREGIVER_LINEAR_RETENTION_FORWARD_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_DISCOVERY_TO_BUSINESS_AUDIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_WEEKLY_VISIT_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_GAPS_IN_CARE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_NPS_CLIENT_SCORE_BKP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_BACKUP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_BACKUP_20210913.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_TOP_OFFENDERS_EXCEPTION_DETAILS_BY_WEEK.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CENSUS_BY_SERVICE_DATE_WEEKLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_TIME_TO_COLLECT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_2_0_WIP_NEW.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_LINEAR_RETENTION_MONTHLY_INNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_OVERTIME.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CAREGIVER_LINEAR_RETENTION_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CAREGIVER_RELATIONSHIP_2_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CONVERSION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_SERVICE_WEEKLY_AUTHORIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_NEW_REFERRALS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ONHOLDCLIENTHISTORY_PA.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_RPT_UNBILLED_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_2_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REFERRED_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_LINEAR_RETENTION_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_OFF_HOLD_CLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_SCHEDULE_METRICS_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CENSUS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_DAILYVISITHOURSCOUNTRECENT4WEEKS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_EVV_VISITS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_WEEKLY_2_0_WIP_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_PAYROLL_EMPLOYEE_DERIVED_WEEKLY_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_BKCP_0525.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.DISCOVERY_TO_BUSINESS_AUDIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_BUSINESS_TO_BUSINESS_AUDIT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REFERRED_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CAREGIVER_MONTHLY_RELATIONSHIP_2_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CENSUS_WIP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_DAILYCLIENTCOUNT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_DAILYVISITHOURSCOUNTRECENT4WEEKSWITHWEEKFIRSTDAY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_NEW_STARTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_ON_HOLD_CLIENTS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_WEEKLY_METRICS_BY_SERVICE_LINE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_RPT_AUTH_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_LINEAR_RETENTION_FORWARD_MONTHLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_TERMED.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_LINEAR_RETENTION_FORWARD_MONTHLY_INNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_DAILY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ACCOUNTS_RECEIVABLE_AGING.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_ADD_NPS_TO_UTILIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_COVID_19_DAILYVISITHOURSCOUNT.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_SERVICE_MONTHLY_AUTHORIZATION.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_PHONE_NUMBERS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_STEP_INCENTIVE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.PROC_MERGEONHOLDCLIENTHISTORY_DATAFLEX.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_STARTED.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_DERIVED_WEEKLY_VISIT_METRICS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY_MS_TEST.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_HOURS_AND_CENSUS_BY_PAYROLL_DATE_WEEKLY_2_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_NPS_CAREGIVER_SCORE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CAREGIVER_LINEAR_RETENTION_FORWARD_MONTHLY_INNER.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REACTIVATED.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_SERVICE_MONTHLY_AUTHORIZATION_BKCP1310.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_SUPERVISOR_BY_SERVICE_MONTH.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_NPS_CLIENT_SCORE_BKP_13042023.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_OVERTIME_2_BACKUP_20210913.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_SCHEDULE_METRICS_WEEKLY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_2_0_BCP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_WEEKLY_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CAREGIVER_EXIT_SURVEY.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENTS_REFERRED_2_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_CLIENT_CAREGIVER_RELATIONSHIP_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_EMPLOYEE_DERIVED_MONTHLY_VISIT_METRICS_W_BILLABLE.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_1_0.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_UTILIZATION_2_0_WIP.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.REPORT.GET_REPORT_FACT_APPLICANT_DETAILS.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.STAGE.GET_STAGE_SANDATAIMPORT_FACT_VISIT_TEST_FULL.sql
# Generated SQL file:  SQL_Files\stored procedure/DW_PROD.STAGE.MERGE_STAGE_SANDATAIMPORT_FACT_VISIT_CHECK.sql
